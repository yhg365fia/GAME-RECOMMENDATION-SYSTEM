# %%
import os

print(os.getcwd())
# Out:
# c:\projects\Game-Recommendation-System\notebook

# %%
import pandas as pd

recommendations = pd.read_csv("../data/recommendations.csv")
games = pd.read_csv("../data/games.csv")
users = pd.read_csv("../data/users.csv")
print(recommendations.head())
print(games.head())
print(users.head())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[80], line 3
#       1 import pandas as pd
# ----> 3 recommendations = pd.read_csv("../data/recommendations.csv")
#       4 games = pd.read_csv("../data/games.csv")
#       5 users = pd.read_csv("../data/users.csv")
#
# File c:\Users\gey82\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\gey82\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:306, in _read(filepath_or_buffer, kwds)
#     303     return parser
#     305 with parser:
# --> 306     return parser.read(nrows)
#
# File c:\Users\gey82\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1947, in TextFileReader.read(self, nrows)
#    1940 nrows = validate_integer("nrows", nrows)
#    1941 try:
#    1942     # error: "ParserBase" has no attribute "read"
#    1943     (
#    1944         index,
#    1945         columns,
#    1946         col_dict,
# -> 1947     ) = self._engine.read(  # type: ignore[attr-defined]
#    1948         nrows
#    1949     )
#    1950 except Exception:
#    1951     self.close()
#
# File c:\Users\gey82\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:217, in CParserWrapper.read(self, nrows)
#     215     chunks = self._reader.read_low_memory(nrows)
#     216     # destructive to chunks
# --> 217     data = _concatenate_chunks(chunks, self.names)
#     218 else:
#     219     data = self._reader.read(nrows)
#
# File c:\Users\gey82\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:359, in _concatenate_chunks(chunks, column_names)
#     357     result[name] = union_categoricals(arrs, sort_categories=False)
#     358 else:
# --> 359     result[name] = concat_compat(arrs)
#     360     if len(non_cat_dtypes) > 1 and result[name].dtype == np.dtype(object):
#     361         warning_columns.append(column_names[name])
#
# File c:\Users\gey82\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\concat.py:78, in concat_compat(to_concat, axis, ea_compat_axis)
#      76 if isinstance(obj, np.ndarray):
#      77     to_concat_arrs = cast("Sequence[np.ndarray]", to_concat)
# ---> 78     return np.concatenate(to_concat_arrs, axis=axis)
#      80 to_concat_eas = cast("Sequence[ExtensionArray]", to_concat)
#      81 if ea_compat_axis:
#      82     # We have 1D objects, that don't support axis keyword
#
# KeyboardInterrupt:

# %%
gamesgenres = pd.read_csv("../data/games_inc.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 gamesgenres = pd.read_csv("../data/games_inc.csv", index_col="AppID")
#
# File c:\Users\gey82\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\gey82\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:306, in _read(filepath_or_buffer, kwds)
#     303     return parser
#     305 with parser:
# --> 306     return parser.read(nrows)
#
# File c:\Users\gey82\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1947, in TextFileReader.read(self, nrows)
#    1940 nrows = validate_integer("nrows", nrows)
#    1941 try:
#    1942     # error: "ParserBase" has no attribute "read"
#    1943     (
#    1944         index,
#    1945         columns,
#    1946         col_dict,
# -> 1947     ) = self._engine.read(  # type: ignore[attr-defined]
#    1948         nrows
#    1949     )
#    1950 except Exception:
#    1951     self.close()
#
# File c:\Users\gey82\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:271, in CParserWrapper.read(self, nrows)
#     269     values = data.pop(i)
#     270 else:
# --> 271     values = data.pop(self.index_col[i])
#     273 if self._should_parse_dates(i):
#     274     values = date_converter(
#     275         values,
#     276         col=(
#    (...)    283         date_format=self.date_format,
#     284     )
#
# KeyError: 'AppID'

# %%
correct_columns = [
    'AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU',
    'Required age', 'Price', 'Discount', 'DLC count', 'About the game',
    'Supported languages', 'Full audio languages', 'Reviews', 'Header image',
    'Website', 'Support url', 'Support email', 'Windows', 'Mac', 'Linux',
    'Metacritic score', 'Metacritic url', 'User score', 'Positive', 'Negative',
    'Score rank', 'Achievements', 'Recommendations', 'Notes',
    'Average playtime forever', 'Average playtime two weeks',
    'Median playtime forever', 'Median playtime two weeks',
    'Developers', 'Publishers', 'Categories', 'Genres', 'Tags',
    'Screenshots', 'Movies'
]

gamesgenres = pd.read_csv(
    "../data/games_inc.csv",
    header=0,          # 기존 헤더 줄은 버리고
    names=correct_columns  # 이 이름들을 강제로 매핑
)

print(gamesgenres.shape)  # (125855, 40) 이 나오면 정상
# Out:
# (125855, 40)

# %%
gamesgenres.head()
# Out:
#      AppID                                   Name  Release date  \
# 0  2539430             Black Dragon Mage Playtest   Aug 1, 2023
# 1   496350  Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016
# 2  1034400      Mystery Solitaire The Black Raven   May 6, 2019
# 3  3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024
# 4  3631080                          Maze Quest VR  Apr 24, 2025
#
#   Estimated owners  Peak CCU  Required age  Price  Discount  DLC count  \
# 0            0 - 0         0             0   0.00         0          0
# 1        0 - 20000         0             0   5.24        65          0
# 2        0 - 20000         0             0   4.99         0          0
# 3        0 - 20000         1             0   8.99         0          1
# 4        0 - 20000         0             0   4.99         0          0
#
#                                       About the game  ...  \
# 0                                                NaN  ...
# 1  Springtime, April: when the cherry trees come ...  ...
# 2  Immerse yourself in the most beloved, mystical...  ...
# 3  synopsis 'Hello, I'm Hiyoro, a new YouTuber!' ...  ...
# 4  Its not just a Maze; its a Quest! Enter the ca...  ...
#
#   Average playtime two weeks Median playtime forever  \
# 0                          0                       0
# 1                          0                       8
# 2                          0                       0
# 3                          0                       0
# 4                          0                       0
#
#   Median playtime two weeks            Developers            Publishers  \
# 0                         0                   NaN                   NaN
# 1                         0                minori            MangaGamer
# 2                         0           Somer Games                8floor
# 3                         0                 유진게임즈                 유진게임즈
# 4                         0  Reality Expanded LLC  Reality Expanded LLC
#
#                                           Categories                   Genres  \
# 0                                                NaN                      NaN
# 1  Single-player,Steam Trading Cards,Steam Cloud,...                Adventure
# 2                       Single-player,Family Sharing                   Casual
# 3    Single-player,Steam Achievements,Family Sharing  Casual,Indie,Simulation
# 4  Single-player,VR Only,Steam Leaderboards,Famil...      Action,Early Access
#
#                                                 Tags  \
# 0                                                NaN
# 1                  Adventure,Visual Novel,Anime,Cute
# 2  Casual,Card Game,Solitaire,Puzzle,Hidden Objec...
# 3                                                NaN
# 4                                                NaN
#
#                                          Screenshots  Movies
# 0  https://shared.akamai.steamstatic.com/store_it...     NaN
# 1  https://shared.akamai.steamstatic.com/store_it...     NaN
# 2  https://shared.akamai.steamstatic.com/store_it...     NaN
# 3  https://shared.akamai.steamstatic.com/store_it...     NaN
# 4  https://shared.akamai.steamstatic.com/store_it...     NaN
#
# [5 rows x 40 columns]

# %%
print(gamesgenres.columns.tolist())
# Out:
# ['AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU', 'Required age', 'Price', 'DiscountDLC count', 'About the game', 'Supported languages', 'Full audio languages', 'Reviews', 'Header image', 'Website', 'Support url', 'Support email', 'Windows', 'Mac', 'Linux', 'Metacritic score', 'Metacritic url', 'User score', 'Positive', 'Negative', 'Score rank', 'Achievements', 'Recommendations', 'Notes', 'Average playtime forever', 'Average playtime two weeks', 'Median playtime forever', 'Median playtime two weeks', 'Developers', 'Publishers', 'Categories', 'Genres', 'Tags', 'Screenshots', 'Movies']

# %%
gamesgenres.info()
gamesgenres.describe()
gamesgenres.columns
gamesgenres.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 125855 entries, 0 to 125854
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   AppID                       125855 non-null  int64
#  1   Name                        125854 non-null  str
#  2   Release date                125855 non-null  str
#  3   Estimated owners            125855 non-null  str
#  4   Peak CCU                    125855 non-null  int64
#  5   Required age                125855 non-null  int64
#  6   Price                       125855 non-null  float64
#  7   Discount                    125855 non-null  int64
#  8   DLC count                   125855 non-null  int64
#  9   About the game              117393 non-null  str
#  10  Supported languages         125855 non-null  str
#  11  Full audio languages        125855 non-null  str
#  12  Reviews                     12181 non-null   str
#  13  Header image                125774 non-null  str
#  14  Website                     50520 non-null   str
#  15  Support url                 55295 non-null   str
#  16  Support email               103225 non-null  str
#  17  Windows                     125855 non-null  bool
#  18  Mac                         125855 non-null  bool
#  19  Linux                       125855 non-null  bool
#  20  Metacritic score            125855 non-null  int64
#  21  Metacritic url              4258 non-null    str
#  22  User score                  125855 non-null  int64
#  23  Positive                    125855 non-null  int64
#  24  Negative                    125855 non-null  int64
#  25  Score rank                  40 non-null      float64
#  26  Achievements                125855 non-null  int64
#  27  Recommendations             125855 non-null  int64
#  28  Notes                       23310 non-null   str
#  29  Average playtime forever    125855 non-null  int64
#  30  Average playtime two weeks  125855 non-null  int64
#  31  Median playtime forever     125855 non-null  int64
#  32  Median playtime two weeks   125855 non-null  int64
#  33  Developers                  117406 non-null  str
#  34  Publishers                  116933 non-null  str
#  35  Categories                  116889 non-null  str
#  36  Genres                      117432 non-null  str
#  37  Tags                        83353 non-null   str
#  38  Screenshots                 119828 non-null  str
#  39  Movies                      0 non-null       float64
# dtypes: bool(3), float64(3), int64(15), str(19)
# memory usage: 35.9 MB
#      AppID                                   Name  Release date  \
# 0  2539430             Black Dragon Mage Playtest   Aug 1, 2023
# 1   496350  Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016
# 2  1034400      Mystery Solitaire The Black Raven   May 6, 2019
# 3  3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024
# 4  3631080                          Maze Quest VR  Apr 24, 2025
#
#   Estimated owners  Peak CCU  Required age  Price  Discount  DLC count  \
# 0            0 - 0         0             0   0.00         0          0
# 1        0 - 20000         0             0   5.24        65          0
# 2        0 - 20000         0             0   4.99         0          0
# 3        0 - 20000         1             0   8.99         0          1
# 4        0 - 20000         0             0   4.99         0          0
#
#                                       About the game  ...  \
# 0                                                NaN  ...
# 1  Springtime, April: when the cherry trees come ...  ...
# 2  Immerse yourself in the most beloved, mystical...  ...
# 3  synopsis 'Hello, I'm Hiyoro, a new YouTuber!' ...  ...
# 4  Its not just a Maze; its a Quest! Enter the ca...  ...
#
#   Average playtime two weeks Median playtime forever  \
# 0                          0                       0
# 1                          0                       8
# 2                          0                       0
# 3                          0                       0
# 4                          0                       0
#
#   Median playtime two weeks            Developers            Publishers  \
# 0                         0                   NaN                   NaN
# 1                         0                minori            MangaGamer
# 2                         0           Somer Games                8floor
# 3                         0                 유진게임즈                 유진게임즈
# 4                         0  Reality Expanded LLC  Reality Expanded LLC
#
#                                           Categories                   Genres  \
# 0                                                NaN                      NaN
# 1  Single-player,Steam Trading Cards,Steam Cloud,...                Adventure
# 2                       Single-player,Family Sharing                   Casual
# 3    Single-player,Steam Achievements,Family Sharing  Casual,Indie,Simulation
# 4  Single-player,VR Only,Steam Leaderboards,Famil...      Action,Early Access
#
#                                                 Tags  \
# 0                                                NaN
# 1                  Adventure,Visual Novel,Anime,Cute
# 2  Casual,Card Game,Solitaire,Puzzle,Hidden Objec...
# 3                                                NaN
# 4                                                NaN
#
#                                          Screenshots  Movies
# 0  https://shared.akamai.steamstatic.com/store_it...     NaN
# 1  https://shared.akamai.steamstatic.com/store_it...     NaN
# 2  https://shared.akamai.steamstatic.com/store_it...     NaN
# 3  https://shared.akamai.steamstatic.com/store_it...     NaN
# 4  https://shared.akamai.steamstatic.com/store_it...     NaN
#
# [5 rows x 40 columns]

# %%
meta = gamesgenres[
    [
        "AppID",
        "Name",
        "Genres",
        "Tags",
        "Categories",
        "About the game"
    ]
].copy()

# %%
meta.info()
meta.describe()
meta.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 125855 entries, 0 to 125854
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   AppID           125855 non-null  int64
#  1   Name            125854 non-null  str
#  2   Genres          117432 non-null  str
#  3   Tags            83353 non-null   str
#  4   Categories      116889 non-null  str
#  5   About the game  117393 non-null  str
# dtypes: int64(1), str(5)
# memory usage: 5.8 MB
# Index(['AppID', 'Name', 'Genres', 'Tags', 'Categories', 'About the game'], dtype='str')

# %%
print(meta.isnull().sum())
# Out:
# AppID                 1
# Name                  0
# Genres             8423
# Tags              42502
# Categories         8966
# About the game     8462
# dtype: int64

# %%
meta[meta['Name'].isnull()]
# Out:
#         AppID Name Genres Tags Categories  \
# 44432  396420  NaN    NaN  NaN        NaN
#
#                                           About the game
# 44432  Spookeningは3Dの恐怖ゲームで、あなたは毎夜に死んでゴーストとして復活します。 村...

# %%
meta = meta.dropna(subset=["Name"])

# %%
meta["Genres"] = meta["Genres"].fillna("")
meta["Categories"] = meta["Categories"].fillna("")
meta["About the game"] = meta["About the game"].fillna("")
meta["Tags"] = meta["Tags"].fillna("")

# %%
meta.head()
# Out:
#      AppID                                   Name                   Genres  \
# 0  2539430             Black Dragon Mage Playtest
# 1   496350  Supipara - Chapter 1 Spring Has Come!                Adventure
# 2  1034400      Mystery Solitaire The Black Raven                   Casual
# 3  3292190            버튜버 파라노이아 - Vtuber Paranoia  Casual,Indie,Simulation
# 4  3631080                          Maze Quest VR      Action,Early Access
#
#                                                 Tags  \
# 0
# 1                  Adventure,Visual Novel,Anime,Cute
# 2  Casual,Card Game,Solitaire,Puzzle,Hidden Objec...
# 3
# 4
#
#                                           Categories  \
# 0
# 1  Single-player,Steam Trading Cards,Steam Cloud,...
# 2                       Single-player,Family Sharing
# 3    Single-player,Steam Achievements,Family Sharing
# 4  Single-player,VR Only,Steam Leaderboards,Famil...
#
#                                       About the game
# 0
# 1  Springtime, April: when the cherry trees come ...
# 2  Immerse yourself in the most beloved, mystical...
# 3  synopsis 'Hello, I'm Hiyoro, a new YouTuber!' ...
# 4  Its not just a Maze; its a Quest! Enter the ca...

# %%
print(meta.columns.tolist())
# Out:
# ['AppID', 'Name', 'Genres', 'Tags', 'Categories', 'About the game']

# %%
meta.iloc[0]
# Out:
# AppID                                2539430
# Name              Black Dragon Mage Playtest
# Genres
# Tags
# Categories
# About the game
# Name: 0, dtype: object

# %%
gamesgenres.iloc[0]
# Out:
# AppID                                                                   2539430
# Name                                                 Black Dragon Mage Playtest
# Release date                                                        Aug 1, 2023
# Estimated owners                                                          0 - 0
# Peak CCU                                                                      0
# Required age                                                                  0
# Price                                                                       0.0
# Discount                                                                      0
# DLC count                                                                     0
# About the game                                                              NaN
# Supported languages                                                          []
# Full audio languages                                                         []
# Reviews                                                                     NaN
# Header image                  https://shared.akamai.steamstatic.com/store_it...
# Website                                                                     NaN
# Support url                                                                 NaN
# Support email                                                               NaN
# Windows                                                                    True
# Mac                                                                       False
# Linux                                                                     False
# Metacritic score                                                              0
# Metacritic url                                                              NaN
# User score                                                                    0
# Positive                                                                      0
# Negative                                                                      0
# Score rank                                                                  NaN
# Achievements                                                                  0
# Recommendations                                                               0
# Notes                                                                       NaN
# Average playtime forever                                                      0
# Average playtime two weeks                                                    0
# Median playtime forever                                                       0
# Median playtime two weeks                                                     0
# Developers                                                                  NaN
# Publishers                                                                  NaN
# Categories                                                                  NaN
# Genres                                                                      NaN
# Tags                                                                        NaN
# Screenshots                   https://shared.akamai.steamstatic.com/store_it...
# Movies                                                                      NaN
# Name: 0, dtype: object
