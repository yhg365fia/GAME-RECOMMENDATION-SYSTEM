# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
import pandas as pd

import os

print(os.getcwd())
# Out:
# c:\projects\Game-Recommendation-System\notebook

# %%
meta = pd.read_csv("../data/meta_preprocessed.csv")

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(
    stop_words="english",
    lowercase=True
)

tfidf_matrix = tfidf.fit_transform(meta["combined_features"])

print(tfidf_matrix.shape)
# Out:
# (117560, 544)

# %%
len(tfidf.get_feature_names_out())
tfidf.get_feature_names_out()
# Out:
# array(['1980s', '1990', '2d', '360', '3d', '40k', '4x', '5d', '6dof',
#        'abstract', 'access', 'accounting', 'achievements', 'action',
#        'addictive', 'adjustable', 'adventure', 'agriculture', 'aliens',
#        'alternate', 'alternatives', 'ambient', 'america', 'american',
#        'animation', 'anime', 'anti', 'anytime', 'apocalyptic', 'app',
#        'arcade', 'archery', 'arena', 'artificial', 'arts', 'assassin',
#        'asymmetric', 'asynchronous', 'atmospheric', 'attack', 'atv',
#        'audio', 'auto', 'automation', 'automobile', 'available',
#        'awkward', 'base', 'baseball', 'based', 'basketball', 'batman',
#        'battle', 'battler', 'beat', 'beautiful', 'benchmark', 'bikes',
#        'birds', 'bit', 'blood', 'bmx', 'board', 'book', 'boomer', 'boss',
#        'bowling', 'boxing', 'builder', 'building', 'bullet', 'camera',
#        'campaign', 'capitalism', 'captions', 'card', 'cards', 'cartoon',
#        'cartoony', 'casual', 'cats', 'character', 'chat', 'cheat',
#        'chess', 'choices', 'choose', 'cinematic', 'city', 'class',
#        'classic', 'click', 'clicker', 'cloud', 'coding', 'cold',
#        'collectathon', 'collectibles', 'collector', 'colony', 'color',
#        'colorful', 'combat', 'comedy', 'comfort', 'comic', 'commentary',
#        'competitive', 'conspiracy', 'content', 'control', 'controller',
#        'controls', 'conversation', 'cooking', 'cozy', 'craft', 'crafting',
#        'crawler', 'creature', 'cricket', 'crime', 'croft', 'cross',
#        'crowdfunded', 'crpg', 'cult', 'custom', 'customization', 'cute',
#        'cyberpunk', 'cycling', 'dark', 'dating', 'death', 'deckbuilder',
#        'deckbuilding', 'deduction', 'defense', 'demons', 'design',
#        'destruction', 'detective', 'development', 'dice', 'difficult',
#        'difficulty', 'dinosaurs', 'diplomacy', 'documentary', 'dog',
#        'dragons', 'drama', 'drawn', 'driving', 'dungeon', 'dungeons',
#        'dwarf', 'dynamic', 'dystopian', 'early', 'economy', 'editing',
#        'editor', 'education', 'electronic', 'elf', 'em', 'emotional',
#        'enabled', 'endings', 'epic', 'episodic', 'escape', 'events',
#        'experience', 'experimental', 'exploration', 'extraction', 'faith',
#        'family', 'fantasy', 'farming', 'fast', 'feature', 'female', 'fi',
#        'fiction', 'fighter', 'fighting', 'film', 'fishing', 'flight',
#        'fmv', 'football', 'foreign', 'fox', 'fps', 'free', 'friendly',
#        'funny', 'futuristic', 'gambling', 'game', 'gamemaker', 'games',
#        'gaming', 'generation', 'god', 'golf', 'gore', 'gothic', 'grand',
#        'graphics', 'great', 'grid', 'gun', 'hack', 'hacking', 'hand',
#        'hardware', 'hdr', 'heist', 'hell', 'hentai', 'hero', 'hex',
#        'hidden', 'historical', 'history', 'hl2', 'hobby', 'hockey',
#        'horror', 'horses', 'humor', 'hunting', 'idler', 'ii',
#        'illuminati', 'illustration', 'immersive', 'includes', 'indie',
#        'input', 'instrumental', 'intelligence', 'intentionally',
#        'interactive', 'inventory', 'investigation', 'isometric', 'jet',
#        'job', 'jrpg', 'jump', 'keeper', 'keyboard', 'kickstarter', 'lan',
#        'lara', 'leaderboards', 'lego', 'lemmings', 'level', 'lgbtq',
#        'life', 'like', 'linear', 'lite', 'local', 'logic', 'loot',
#        'looter', 'lore', 'lovecraftian', 'machine', 'magic', 'mahjong',
#        'management', 'manipulation', 'mars', 'martial', 'massively',
#        'masterpiece', 'match', 'matching', 'matter', 'mature', 'mechs',
#        'medical', 'medieval', 'memes', 'menus', 'metroidvania',
#        'military', 'mini', 'minigames', 'minimalist', 'mining', 'mmo',
#        'mmorpg', 'moba', 'mod', 'moddable', 'modeling', 'modern', 'mods',
#        'motocross', 'motorbike', 'mouse', 'movement', 'movie', 'multi',
#        'multiplayer', 'multiple', 'music', 'musou', 'mystery',
#        'mythology', 'narrated', 'narration', 'narrative', 'nature',
#        'naval', 'ninja', 'noir', 'nonlinear', 'nostalgia',
#        'notifications', 'novel', 'nsfw', 'nudity', 'object', 'offroad',
#        'old', 'online', 'op', 'open', 'option', 'options', 'otome',
#        'outbreak', 'paced', 'parkour', 'parody', 'partial', 'party',
#        'pause', 'perma', 'person', 'philosophical', 'phone', 'photo',
#        'physics', 'pinball', 'pirates', 'pixel', 'platform', 'platformer',
#        'play', 'playable', 'player', 'point', 'political', 'politics',
#        'pool', 'post', 'precision', 'procedural', 'production',
#        'programming', 'protagonist', 'psychedelic', 'psychological',
#        'publishing', 'purchases', 'puzzle', 'pve', 'pvp', 'quick',
#        'racing', 'rails', 'real', 'realistic', 'reboot', 'relaxing',
#        'remake', 'remote', 'replay', 'require', 'resource', 'retro',
#        'rhythm', 'rich', 'robots', 'rock', 'rogue', 'roguelike',
#        'roguevania', 'romance', 'rome', 'room', 'royale', 'rpg',
#        'rpgmaker', 'rts', 'rugby', 'runner', 'rush', 'sailing', 'sandbox',
#        'satire', 'save', 'scare', 'school', 'sci', 'science', 'score',
#        'screen', 'scroller', 'sdk', 'sequel', 'sexual', 'shared',
#        'sharing', 'shoot', 'shooter', 'shop', 'short', 'silent', 'sim',
#        'simulation', 'simulator', 'single', 'singleplayer', 'size',
#        'skateboarding', 'skating', 'skiing', 'slash', 'sniper', 'snooker',
#        'snow', 'snowboarding', 'soccer', 'social', 'software', 'sokoban',
#        'solitaire', 'souls', 'sound', 'soundtrack', 'source', 'space',
#        'spaceships', 'spectacle', 'speech', 'spelling', 'split', 'sports',
#        'stats', 'stealth', 'steam', 'steampunk', 'steamvr', 'stereo',
#        'stick', 'story', 'strategy', 'stylized', 'submarine', 'subtitle',
#        'superhero', 'supernatural', 'support', 'supported', 'surreal',
#        'surround', 'survival', 'swordplay', 'tablet', 'tabletop',
#        'tactical', 'tactics', 'tanks', 'team', 'tennis', 'text',
#        'thriller', 'tile', 'time', 'timed', 'timeline', 'touch', 'tower',
#        'tracked', 'trackir', 'trading', 'traditional', 'training',
#        'trains', 'transhumanism', 'transportation', 'travel', 'trivia',
#        'turn', 'tutorial', 'tv', 'twin', 'typing', 'underground',
#        'underwater', 'unforgiving', 'utilities', 'value', 'valve',
#        'vampire', 'vehicular', 'video', 'vikings', 'villain', 'violent',
#        'vision', 'visual', 'voice', 'volleyball', 'volume', 'voxel', 'vr',
#        'walking', 'war', 'wargame', 'warhammer', 'web', 'werewolves',
#        'western', 'wholesome', 'word', 'workshop', 'world', 'wrestling',
#        'written', 'zombies'], dtype=object)

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
cosine_similarity(tfidf_matrix[0], tfidf_matrix)
# Out:
# array([[1.        , 0.0342483 , 0.20506763, ..., 0.17028972, 0.41739856,
#         0.15257807]], shape=(1, 117560))
